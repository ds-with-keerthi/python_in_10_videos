# %% [markdown]
# # Library

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
import pandas as pd

# %% [markdown]
# # Data

# %%
df = pd.read_csv('Public holidays 2024 - Sheet1.csv')

# %%
df
# Out:
#    Month  Date        Day                          Name
# 0    Jan     1     Monday                      New year
# 1    Jan    15     Monday                        Pongal
# 2    Jan    16    Tuesday             Thiruvalluvar day
# 3    Jan    17  Wednesday             Uzhavar Thirunaal
# 4    Jan    25   Thursday                   Thai poosam
# 5    Jan    26     Friday                  Republic day
# 6    Mar    29     Friday                   Good Friday
# 7    Apr     1     Monday  Annual closing day for banks
# 8    Apr     9    Tuesday               Telugu New Year
# 9    Apr    11   Thursday                        Ramzan
# 10   Apr    14     Sunday                Tamil New Year
# 11   Apr    21    Sunday              Mahaveer Jayanthi
# 12  May      1  Wednesday                      May Day
# 13   Jun    17     Monday                        Bakrid
# 14   Jul    17  Wednesday                      Muharram
# 15   Aug    15   Thursday              Independence day
# 16   Aug    26     Monday              Krishna Jayanthi
# 17  Sep      7   Saturday          Vinayagar Chathurthi
# 18  Sep     16     Monday                   Miladi nabi
# 19   Oct     2  Wednesday               Gandhi jeyanthi
# 20   Oct    11     Friday                  Ayutha Pooja
# 21   Oct    12   Saturday                 Vijaya Dasami
# 22   Oct    31   Thursday                     Deepavali
# 23   Dec    25  Wednesday                     Christmas

# %% [markdown]
# # Line Plot

# %%
sns.lineplot(data=df, x='Month', y='Name', hue='Day')
# Out:
# <Axes: xlabel='Month', ylabel='Name'>

# %% [markdown]
# # Bar Plot

# %%
mont_wise_groupby = df.groupby('Month').count()

# %%
mont_wise_groupby
# Out:
#        Date  Day  Name
# Month
# Apr       5    5     5
# Aug       2    2     2
# Dec       1    1     1
# Jan       6    6     6
# Jul       1    1     1
# Jun       1    1     1
# Mar       1    1     1
# May       1    1     1
# Oct       4    4     4
# Sep       2    2     2

# %%
sns.barplot(data=mont_wise_groupby, x='Month', y='Date')
# Out:
# <Axes: xlabel='Month', ylabel='Date'>

# %%
plt.figure(figsize=(20,15))
sns.barplot(data=df, x='Month', y='Date', hue='Name', palette='Set2')
# Out:
# <Axes: xlabel='Month', ylabel='Date'>

# %% [markdown]
# # Histogram

# %%
sns.histplot(data=df, x='Date', bins=3, kde=True)
# Out:
# <Axes: xlabel='Date', ylabel='Count'>

# %% [markdown]
# # ScatterPlot

# %%
sns.scatterplot(data=df, x='Date', y = 'Name', hue='Month')
# Out:
# <Axes: xlabel='Date', ylabel='Name'>

# %% [markdown]
# # Box plot

# %%
df['Date'].describe()
# Out:
# count    24.000000
# mean     15.208333
# std       8.949030
# min       1.000000
# 25%      10.500000
# 50%      15.500000
# 75%      22.000000
# max      31.000000
# Name: Date, dtype: float64

# %%
sns.boxplot(data=df)
sns.swarmplot(data=df, color='red')
# Out:
# <Axes: >

# %%
df.loc[24] = {'Month': 'Jan', 'Date': 100, 'Day': 'Monday', 'Name': 'summa'}

# %% [markdown]
# # Violin Plot

# %%
sns.violinplot(data=df)
# Out:
# <Axes: >

# %%
sns.histplot(x='Date', data=df, kde=True)
# Out:
# <Axes: xlabel='Date', ylabel='Count'>

# %% [markdown]
# # HeatMap

# %%
month_dict = {'Jan': 1,
             'Feb' : 2,
             'Mar' : 3,
             'Apr' : 4,
             'May ' : 5,
             'Jun' : 6,
             'Jul' : 7,
             'Aug' : 8,
             'Sep ' : 9,
             'Oct' : 10,
             'Nov' : 11,
             'Dec' : 12}
df['Month_Number']  =df['Month'].map(month_dict)

# %%
df.corr(numeric_only=True)
# Out:
#                   Date  Month_Number
# Date          1.000000      0.012459
# Month_Number  0.012459      1.000000

# %%
sns.heatmap(df.corr(numeric_only=True), annot=True)
# Out:
# <Axes: >

# %% [markdown]
# # FacetGrid

# %%
df
# Out:
#    Month  Date        Day                          Name  Month_Number
# 0    Jan     1     Monday                      New year             1
# 1    Jan    15     Monday                        Pongal             1
# 2    Jan    16    Tuesday             Thiruvalluvar day             1
# 3    Jan    17  Wednesday             Uzhavar Thirunaal             1
# 4    Jan    25   Thursday                   Thai poosam             1
# 5    Jan    26     Friday                  Republic day             1
# 6    Mar    29     Friday                   Good Friday             3
# 7    Apr     1     Monday  Annual closing day for banks             4
# 8    Apr     9    Tuesday               Telugu New Year             4
# 9    Apr    11   Thursday                        Ramzan             4
# 10   Apr    14     Sunday                Tamil New Year             4
# 11   Apr    21    Sunday              Mahaveer Jayanthi             4
# 12  May      1  Wednesday                      May Day              5
# 13   Jun    17     Monday                        Bakrid             6
# 14   Jul    17  Wednesday                      Muharram             7
# 15   Aug    15   Thursday              Independence day             8
# 16   Aug    26     Monday              Krishna Jayanthi             8
# 17  Sep      7   Saturday          Vinayagar Chathurthi             9
# 18  Sep     16     Monday                   Miladi nabi             9
# 19   Oct     2  Wednesday               Gandhi jeyanthi            10
# 20   Oct    11     Friday                  Ayutha Pooja            10
# 21   Oct    12   Saturday                 Vijaya Dasami            10
# 22   Oct    31   Thursday                     Deepavali            10
# 23   Dec    25  Wednesday                     Christmas            12

# %%
x = sns.FacetGrid(data= df, col='Day')
x = x.map(plt.hist, 'Month', edgecolor='black')

# %% [markdown]
# # Joint plot

# %%
sns.jointplot(data=df, x='Month_Number', y= 'Date', kind='reg')

# %% [markdown]
# # PairPlot

# %%
sns.pairplot(data=df)
