# %% [markdown]
# # Libraries

# %%
import matplotlib.pyplot as plt

# %%
import pandas as pd

# %% [markdown]
# # Load data

# %%
cyclones = pd.read_csv("Chennai cyclones.csv")

# %%
cyclones.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Year          11 non-null     int64
#  1   Cyclone Name  11 non-null     object
#  2   Formed        11 non-null     object
#  3   Dissipated    11 non-null     object
#  4   Fatalities    11 non-null     int64
#  5   Damage        11 non-null     object
# dtypes: int64(2), object(4)
# memory usage: 660.0+ bytes

# %%
cyclones
# Out:
#     Year Cyclone Name  Formed Dissipated  Fatalities          Damage
# 0   2008        Nisha  Nov 25     Nov 29         204    $800 million
# 1   2010          Jal   Nov 1     Nov 12         118  $1.73 billion
# 2   2011        Thane  Dec 25     Dec 31          48    $235 million
# 3   2012        Nilam  Oct 28      Nov 1          75   $56.7 million
# 4   2013         Madi  May 10     Dec 13         323   $5.09 billion
# 5   2016       Vardah   Dec 6     Dec 13          47   $3.38 billion
# 6   2017        Ockhi  Nov 29      Dec 6         318    $920 million
# 7   2018         Gaja  Nov 10     Nov 22          52    $775 million
# 8   2020        nivar  Nov 23     Nov 27          14    $600 million
# 9   2022       Aasani   May 7     May 12           3   $1.57 million
# 10  2023     Michaung   Dec 1      Dec 6          17     $15 million

# %% [markdown]
# # Basic line plot

# %%
plt.plot(cyclones['Year'], cyclones['Fatalities'])
plt.xlabel('Year')
plt.ylabel('death rate')
plt.title('Chennai floods')
plt.show()

# %% [markdown]
# # Plot beautifiers (colour, marker, linewidth, grid, linestyle, markersize)

# %%
plt.plot(cyclones['Year'], cyclones['Fatalities'], color='red', marker = 'o', linewidth=5, linestyle='dotted', markersize='15')
plt.grid(True)
plt.xlabel('Year')
plt.ylabel('death rate')
plt.title('Chennai floods')
plt.show()

# %% [markdown]
# # Multiple plots

# %%
fig = plt.figure(figsize=(25, 15))

ax1 = fig.add_subplot(2,2,1)

plt.plot(cyclones['Year'], cyclones['Fatalities'], color='red', marker = 'o', linewidth=5, linestyle='dotted', markersize='15')
plt.grid(True)
plt.xlabel('Year')
plt.ylabel('death rate')
plt.title('Chennai floods')

ax2 = fig.add_subplot(2,2,2)

plt.plot(cyclones['Cyclone Name'], cyclones['Fatalities'], color='blue', marker = 'o', linewidth=5, linestyle='dotted', markersize='15')
plt.grid(True)
plt.xlabel('name of cyclone')
plt.ylabel('death rate')

ax3 = fig.add_subplot(2,2,3)

plt.plot(cyclones['Formed'], cyclones['Fatalities'], color='hotpink', marker = 'o', linewidth=5, linestyle='dotted', markersize='15')
plt.grid(True)
plt.xlabel('cyclone birth')
plt.ylabel('death rate')

ax4 = fig.add_subplot(2,2,4)

plt.plot(cyclones['Dissipated'], cyclones['Fatalities'], color='purple', marker = 'o', linewidth=5, linestyle='dotted', markersize='15')
plt.grid(True)
plt.xlabel('cyclone death')
plt.ylabel('death rate')
# Out:
# Text(0, 0.5, 'death rate')

# %% [markdown]
# # Bar plot

# %%
def convert_damages(damages):
    endresult = []
    for i in damages:
        values = i.split()
        # print(values)
        num = values[0][1:]
        print(type(num))
        if values[1] == 'million':
            result = float(num) * 1000000
        else:
            result = float(num) * 1000000000
        endresult.append(result)
    return endresult

# %%
damage_converted = convert_damages(cyclones['Damage'])
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>

# %%
damage_converted
# Out:
# [800000000.0,
#  1730000000.0,
#  235000000.0,
#  56700000.0,
#  5090000000.0,
#  3380000000.0,
#  920000000.0,
#  775000000.0,
#  600000000.0,
#  1570000.0,
#  15000000.0]

# %%
cyclones['Damage_converted'] = damage_converted

# %%
cyclones
# Out:
#     Year Cyclone Name  Formed Dissipated  Fatalities          Damage  \
# 0   2008        Nisha  Nov 25     Nov 29         204    $800 million
# 1   2010          Jal   Nov 1     Nov 12         118  $1.73 billion
# 2   2011        Thane  Dec 25     Dec 31          48    $235 million
# 3   2012        Nilam  Oct 28      Nov 1          75   $56.7 million
# 4   2013         Madi  May 10     Dec 13         323   $5.09 billion
# 5   2016       Vardah   Dec 6     Dec 13          47   $3.38 billion
# 6   2017        Ockhi  Nov 29      Dec 6         318    $920 million
# 7   2018         Gaja  Nov 10     Nov 22          52    $775 million
# 8   2020        nivar  Nov 23     Nov 27          14    $600 million
# 9   2022       Aasani   May 7     May 12           3   $1.57 million
# 10  2023     Michaung   Dec 1      Dec 6          17     $15 million
#
#     Damage_converted
# 0       8.000000e+08
# 1       1.730000e+09
# 2       2.350000e+08
# 3       5.670000e+07
# 4       5.090000e+09
# 5       3.380000e+09
# 6       9.200000e+08
# 7       7.750000e+08
# 8       6.000000e+08
# 9       1.570000e+06
# 10      1.500000e+07

# %%
fig = plt.figure(figsize=(25, 10))
ax = fig.add_subplot(1,1,1)

ax.xaxis.label.set_color('Green')        #setting up X-axis label color to yellow
ax.yaxis.label.set_color('blue')          #setting up Y-axis label color to blue

ax.tick_params(axis='x', colors='red')    #setting up X-axis tick color to red
ax.tick_params(axis='y', colors='black') 


plt.bar(cyclones['Cyclone Name'], cyclones['Damage_converted'])
plt.xlabel('name of cyclone')
plt.xticks(rotation=45)
plt.ylabel('damages')
plt.title('which cyclone is expensive?')
plt.show()

# %% [markdown]
# # Histogram

# %%
plt.hist(cyclones['Year'], bins=5, edgecolor='black')
plt.show()

# %% [markdown]
# # Scatterplot

# %%
cyclones['cyclone_birth_month'] = cyclones['Formed'].apply(lambda x: x.split()[0])

# %%
cyclones
# Out:
#     Year Cyclone Name  Formed Dissipated  Fatalities          Damage  \
# 0   2008        Nisha  Nov 25     Nov 29         204    $800 million
# 1   2010          Jal   Nov 1     Nov 12         118  $1.73 billion
# 2   2011        Thane  Dec 25     Dec 31          48    $235 million
# 3   2012        Nilam  Oct 28      Nov 1          75   $56.7 million
# 4   2013         Madi  May 10     Dec 13         323   $5.09 billion
# 5   2016       Vardah   Dec 6     Dec 13          47   $3.38 billion
# 6   2017        Ockhi  Nov 29      Dec 6         318    $920 million
# 7   2018         Gaja  Nov 10     Nov 22          52    $775 million
# 8   2020        nivar  Nov 23     Nov 27          14    $600 million
# 9   2022       Aasani   May 7     May 12           3   $1.57 million
# 10  2023     Michaung   Dec 1      Dec 6          17     $15 million
#
#     Damage_converted cyclone_birth_month
# 0       8.000000e+08                 Nov
# 1       1.730000e+09                 Nov
# 2       2.350000e+08                 Dec
# 3       5.670000e+07                 Oct
# 4       5.090000e+09                 May
# 5       3.380000e+09                 Dec
# 6       9.200000e+08                 Nov
# 7       7.750000e+08                 Nov
# 8       6.000000e+08                 Nov
# 9       1.570000e+06                 May
# 10      1.500000e+07                 Dec

# %%
plt.scatter(cyclones['Cyclone Name'], cyclones['cyclone_birth_month'])
plt.xticks(rotation=45)
plt.show()

# %%
cyclones['Formed']
# Out:
# 0     Nov 25
# 1      Nov 1
# 2     Dec 25
# 3     Oct 28
# 4     May 10
# 5      Dec 6
# 6     Nov 29
# 7     Nov 10
# 8     Nov 23
# 9      May 7
# 10     Dec 1
# Name: Formed, dtype: object

# %% [markdown]
# # Pie chart

# %%
cyclones
# Out:
#     Year Cyclone Name  Formed Dissipated  Fatalities          Damage  \
# 0   2008        Nisha  Nov 25     Nov 29         204    $800 million
# 1   2010          Jal   Nov 1     Nov 12         118  $1.73 billion
# 2   2011        Thane  Dec 25     Dec 31          48    $235 million
# 3   2012        Nilam  Oct 28      Nov 1          75   $56.7 million
# 4   2013         Madi  May 10     Dec 13         323   $5.09 billion
# 5   2016       Vardah   Dec 6     Dec 13          47   $3.38 billion
# 6   2017        Ockhi  Nov 29      Dec 6         318    $920 million
# 7   2018         Gaja  Nov 10     Nov 22          52    $775 million
# 8   2020        nivar  Nov 23     Nov 27          14    $600 million
# 9   2022       Aasani   May 7     May 12           3   $1.57 million
# 10  2023     Michaung   Dec 1      Dec 6          17     $15 million
#
#     Damage_converted cyclone_birth_month  death_percentage
# 0       8.000000e+08                 Nov         16.735029
# 1       1.730000e+09                 Nov          9.680066
# 2       2.350000e+08                 Dec          3.937654
# 3       5.670000e+07                 Oct          6.152584
# 4       5.090000e+09                 May         26.497129
# 5       3.380000e+09                 Dec          3.855619
# 6       9.200000e+08                 Nov         26.086957
# 7       7.750000e+08                 Nov          4.265792
# 8       6.000000e+08                 Nov          1.148482
# 9       1.570000e+06                 May          0.246103
# 10      1.500000e+07                 Dec          1.394586

# %%
cyclones['death_percentage'] = cyclones['Fatalities'] / cyclones['Fatalities'].sum() * 100

# %%
plt.figure(figsize=(15,10))
plt.pie(cyclones['death_percentage'], labels= cyclones['Cyclone Name'], shadow=True)
# Out:
# ([<matplotlib.patches.Wedge at 0x1e0d10c28a0>,
#   <matplotlib.patches.Wedge at 0x1e0d10bcdd0>,
#   <matplotlib.patches.Wedge at 0x1e0d10c2d80>,
#   <matplotlib.patches.Wedge at 0x1e0d10c33e0>,
#   <matplotlib.patches.Wedge at 0x1e0d10c3890>,
#   <matplotlib.patches.Wedge at 0x1e0d10c3dd0>,
#   <matplotlib.patches.Wedge at 0x1e0d10c83e0>,
#   <matplotlib.patches.Wedge at 0x1e0d10c8920>,
#   <matplotlib.patches.Wedge at 0x1e0d10c8e60>,
#   <matplotlib.patches.Wedge at 0x1e0d10c9520>,
#   <matplotlib.patches.Wedge at 0x1e0d10c9a90>],
#  [Text(0.9514445279396084, 0.5520446632780501, 'Nisha'),
#   Text(0.2348919458741886, 1.0746282025721443, 'Jal'),
#   Text(-0.23212170694976872, 1.0752299815215003, 'Thane'),
#   Text(-0.5557186141628047, 0.9493033350162488, 'Nilam'),
#   Text(-1.0998684932729645, 0.01700874790979364, 'Madi'),
#   Text(-0.6504564743458975, -0.8870774346028113, 'Vardah'),
#   Text(0.333441472647656, -1.0482446204577263, 'Ockhi'),
#   Text(1.0478140865160521, -0.3347919355338948, 'Gaja'),
#   Text(1.0893649023991394, -0.1525913150245247, 'nivar'),
#   Text(1.0950027696255473, -0.10473268120496498, 'Aasani'),
#   Text(1.0989444388133986, -0.04817800744223705, 'Michaung')])
