# %% [markdown]
# # Library installation

# %%
import pandas as pd

# %%
import numpy as np

# %% [markdown]
# # Pandas Series

# %% [markdown]
# ### how to create?

# %%
veges = ['beetroot', 'carrot', 'tomato', 'kovakkai', 'coconut']

# %%
veges_series = pd.Series(veges, index=['purple', 'orange', 'red','green','white'])

# %%
veges_series
# Out:
# purple    beetroot
# orange      carrot
# red         tomato
# green     kovakkai
# white      coconut
# dtype: object

# %%
vege_dict = {'red': 'tomato','green': 'kovakkai'}

# %%
vege_dict_series = pd.Series(vege_dict)

# %%
vege_dict_series
# Out:
# red        tomato
# green    kovakkai
# dtype: object

# %% [markdown]
# ### How to access?

# %%
veges_series['white']
# Out:
# 'coconut'

# %%
vege_dict_series['orange'] = 'carrot'

# %%
vege_dict_series
# Out:
# red        tomato
# green    kovakkai
# dtype: object

# %%
vege_dict_series.drop(['orange'], inplace=True)

# %% [markdown]
# ### Series elements can be hetrogeneous & nested too!

# %%
veges_dict = {'red': ['tomato', 'redchilli'], 'green': 'kovakkai'}

# %%
new_veges_series = pd.Series(veges_dict)

# %%
type(new_veges_series[1])
# Out:
# C:\Users\keert\AppData\Local\Temp\ipykernel_28472\189875207.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   type(new_veges_series[1])
# str

# %% [markdown]
# # Pandas Datasframe

# %% [markdown]
# ### how to create?

# %%
data = { 'vegetables': ['beetroot', 'carrot', 'redchilli', 'beans', 'coconut'],
       'color' : ['purple', 'orange', 'red', 'green', 'white'],
        'unit' : ['1kg', '1kg','1kg','1kg','1piece'],
       'min' : [25, 35, 33, 40, 'seventeen'],
       'max': [40, 45, 90, 45, 38],
       }

# %%
koyambed_market = pd.DataFrame(data)

# %%
koyambed_market
# Out:
#   vegetables     color    unit        min  max
# a   beetroot    purple     1kg         15   40
# b     carrot    orange     1kg         25   45
# c     tomato    tomato     1kg         53   90
# d   kovakkai  kovakkai     1kg         30   45
# e    coconut   coconut  1piece  seventeen   38

# %%
koyambed_market.index
# Out:
# Index(['a', 'b', 'c', 'd', 'e'], dtype='object')

# %% [markdown]
# ### How to access?

# %%
koyambed_market['unit']
# Out:
# a       1kg
# b       1kg
# c       1kg
# d       1kg
# e    1piece
# Name: unit, dtype: object

# %%
koyambed_market.loc['a', 'unit']
# Out:
# '1kg'

# %%
koyambed_market.iloc[0:3, 0:3]
# Out:
#   vegetables   color unit
# a   beetroot  purple  1kg
# b     carrot  orange  1kg
# c     tomato  tomato  1kg

# %% [markdown]
# ### Adding and removing

# %%
koyambed_market
# Out:
#   vegetables     color    unit        min  max
# a   beetroot    purple     1kg         15   40
# b     carrot    orange     1kg         25   45
# c     tomato    tomato     1kg         53   90
# d   kovakkai  kovakkai     1kg         30   45
# e    coconut   coconut  1piece  seventeen   38

# %%
koyambed_market.loc['f'] = {'vegetables': 'poosanikai', 'color': 'yellow', 'unit': '1piece', 'min' : 10, 'max' : 30}

# %%
koyambed_market
# Out:
#    vegetables     color    unit        min  max
# a    beetroot    purple     1kg         15   40
# b      carrot    orange     1kg         25   45
# c      tomato    tomato     1kg         53   90
# d    kovakkai  kovakkai     1kg         30   45
# e     coconut   coconut  1piece  seventeen   38
# f  poosanikai    yellow  1piece         10   30

# %%
koyambed_market['average'] = [20, 35, 75, 35, 25, 20]

# %%
koyambed_market
# Out:
#   vegetables     color    unit        min  max
# a   beetroot    purple     1kg         15   40
# b     carrot    orange     1kg         25   45
# c     tomato    tomato     1kg         53   90
# d   kovakkai  kovakkai     1kg         30   45
# e    coconut   coconut  1piece  seventeen   38

# %%
koyambed_market.drop(['average'], axis=1, inplace=True)

# %% [markdown]
# ### Handle missing values - isna, sum, any, fillna, dropna

# %%
koyambed_market
# Out:
#   vegetables     color    unit        min  max
# a   beetroot    purple     1kg         15   40
# b     carrot    orange     1kg         25   45
# c     tomato    tomato     1kg         53   90
# d   kovakkai  kovakkai     1kg         30   45
# e    coconut   coconut  1piece  seventeen   38

# %%
koyambed_market.isna().sum()
# Out:
# vegetables    0
# color         0
# unit          0
# min           0
# max           0
# dtype: int64

# %%
koyambed_market['season'] = [True, True, False, False, np.nan]

# %%
koyambed_market
# Out:
#   vegetables     color    unit        min  max season
# a   beetroot    purple     1kg         15   40   True
# b     carrot    orange     1kg         25   45   True
# c     tomato    tomato     1kg         53   90  False
# d   kovakkai  kovakkai     1kg         30   45  False
# e    coconut   coconut  1piece  seventeen   38    NaN

# %%
koyambed_market.isna().sum()
# Out:
# vegetables    0
# color         0
# unit          0
# min           0
# max           0
# season        0
# dtype: int64

# %%
koyambed_market.fillna(False, inplace= True)
# Out:
# C:\Users\keert\AppData\Local\Temp\ipykernel_28472\2257933256.py:1: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   koyambed_market.fillna(False, inplace= True)

# %%
koyambed_market
# Out:
#   vegetables     color    unit        min  max season
# a   beetroot    purple     1kg         15   40   True
# b     carrot    orange     1kg         25   45   True
# c     tomato    tomato     1kg         53   90  False
# d   kovakkai  kovakkai     1kg         30   45  False
# e    coconut   coconut  1piece  seventeen   38    NaN

# %%
koyambed_market.dropna(axis=0)
# Out:
#   vegetables     color unit min  max season
# a   beetroot    purple  1kg  15   40   True
# b     carrot    orange  1kg  25   45   True
# c     tomato    tomato  1kg  53   90  False
# d   kovakkai  kovakkai  1kg  30   45  False

# %% [markdown]
# ### Apply lambda

# %%
koyambed_market
# Out:
#   vegetables     color    unit        min  max
# a   beetroot    purple     1kg         15   45
# b     carrot    orange     1kg         25   50
# c     tomato    tomato     1kg         53   95
# d   kovakkai  kovakkai     1kg         30   50
# e    coconut   coconut  1piece  seventeen   43

# %%
koyambed_market['max'] = koyambed_market['max'].apply(lambda x: x+5)

# %% [markdown]
# ### data aggregating & grouping

# %%
koyambed_market
# Out:
#   vegetables   color    unit        min  max
# a   beetroot  purple     1kg         15   40
# b     carrot  orange     1kg         25   45
# c     tomato     red     1kg         53   90
# d   kovakkai   green     1kg         30   45
# e    coconut   white  1piece  seventeen   38

# %%
koyambed_market['max'].count()
# Out:
# 5

# %%
koyambed_market.groupby(['unit','max']).sum()
# Out:
#                 vegetables        color        min
# unit   max
# 1kg    40         beetroot       purple         15
#        45   carrotkovakkai  orangegreen         55
#        90           tomato          red         53
# 1piece 38          coconut        white  seventeen

# %% [markdown]
# ### Join dataframes

# %%
koyambed_market
# Out:
#   vegetables   color    unit        min  max
# 0   beetroot  purple     1kg         25   40
# 1     carrot  orange     1kg         35   45
# 2     tomato     red     1kg         33   90
# 3   kovakkai   green     1kg         40   45
# 4    coconut   white  1piece  seventeen   38

# %%
thiruvanmiyur_market
# Out:
#   vegetables   color    unit        min  max
# 0   beetroot  purple     1kg         25   40
# 1     carrot  orange     1kg         35   45
# 2  redchilli     red     1kg         33   90
# 3      beans   green     1kg         40   45
# 4    coconut   white  1piece  seventeen   38

# %%
pd.concat([koyambed_market, thiruvanmiyur_market], axis=1)
# Out:
#   vegetables   color    unit        min  max vegetables   color    unit  \
# 0   beetroot  purple     1kg         25   40   beetroot  purple     1kg
# 1     carrot  orange     1kg         35   45     carrot  orange     1kg
# 2     tomato     red     1kg         33   90  redchilli     red     1kg
# 3   kovakkai   green     1kg         40   45      beans   green     1kg
# 4    coconut   white  1piece  seventeen   38    coconut   white  1piece
#
#          min  max
# 0         25   40
# 1         35   45
# 2         33   90
# 3         40   45
# 4  seventeen   38

# %%
pd.merge(koyambed_market, thiruvanmiyur_market, on='vegetables', how='right')
# Out:
#   vegetables color_x  unit_x      min_x  max_x color_y  unit_y      min_y  \
# 0   beetroot  purple     1kg         25   40.0  purple     1kg         25
# 1     carrot  orange     1kg         35   45.0  orange     1kg         35
# 2  redchilli     NaN     NaN        NaN    NaN     red     1kg         33
# 3      beans     NaN     NaN        NaN    NaN   green     1kg         40
# 4    coconut   white  1piece  seventeen   38.0   white  1piece  seventeen
#
#    max_y
# 0     40
# 1     45
# 2     90
# 3     45
# 4     38

# %% [markdown]
# ### read from different source

# %%
pd.read_csv("market.csv")
# Out:
#   Vegatable   Color    Unit        Min  Max
# 0  beetroot  purple     1kg         15   40
# 1    carrot  orange     1kg         25   45
# 2    tomato     red     1kg         53   90
# 3  kovakkai   green     1kg         30   45
# 4   coconut   white  1piece  seventeen   38
